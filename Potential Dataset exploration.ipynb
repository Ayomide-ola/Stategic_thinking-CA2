# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Total Births, Deaths and Marriages Registered.csv")
df.head(20)
# Out:
#          Statistic Label Quarter  State    UNIT   VALUE
# 0   Marriages Registered  1960Q1  State  Number  2987.0
# 1   Marriages Registered  1960Q2  State  Number  3501.0
# 2   Marriages Registered  1960Q3  State  Number  5900.0
# 3   Marriages Registered  1960Q4  State  Number  3106.0
# 4   Marriages Registered  1961Q1  State  Number  2179.0
# 5   Marriages Registered  1961Q2  State  Number  3959.0
# 6   Marriages Registered  1961Q3  State  Number  5722.0
# 7   Marriages Registered  1961Q4  State  Number  3280.0
# 8   Marriages Registered  1962Q1  State  Number  2732.0
# 9   Marriages Registered  1962Q2  State  Number  3385.0
# 10  Marriages Registered  1962Q3  State  Number  6157.0
# 11  Marriages Registered  1962Q4  State  Number  3135.0
# 12  Marriages Registered  1963Q1  State  Number  2743.0
# 13  Marriages Registered  1963Q2  State  Number  3342.0
# 14  Marriages Registered  1963Q3  State  Number  5816.0
# 15  Marriages Registered  1963Q4  State  Number  3397.0
# ...

# %%
df.tail(20)
# Out:
#                           Statistic Label Quarter  State    UNIT  VALUE
# 4534  Average age of mothers giving birth  2018Q2  State  Number    NaN
# 4535  Average age of mothers giving birth  2018Q3  State  Number    NaN
# 4536  Average age of mothers giving birth  2018Q4  State  Number    NaN
# 4537  Average age of mothers giving birth  2019Q1  State  Number    NaN
# 4538  Average age of mothers giving birth  2019Q2  State  Number    NaN
# 4539  Average age of mothers giving birth  2019Q3  State  Number    NaN
# 4540  Average age of mothers giving birth  2019Q4  State  Number    NaN
# 4541  Average age of mothers giving birth  2020Q1  State  Number    NaN
# 4542  Average age of mothers giving birth  2020Q2  State  Number    NaN
# 4543  Average age of mothers giving birth  2020Q3  State  Number    NaN
# 4544  Average age of mothers giving birth  2020Q4  State  Number    NaN
# 4545  Average age of mothers giving birth  2021Q1  State  Number    NaN
# ...

# %%
my_value = 'Births Registered'
results = df.loc[df['Statistic Label'] == my_value]

# %%
results.head()
# Out:
#         Statistic Label Quarter  State    UNIT    VALUE
# 1265  Births Registered  1960Q1  State  Number  14614.0
# 1266  Births Registered  1960Q2  State  Number  16494.0
# 1267  Births Registered  1960Q3  State  Number  15612.0
# 1268  Births Registered  1960Q4  State  Number  14010.0
# 1269  Births Registered  1961Q1  State  Number  14692.0

# %%
df.shape
# Out:
# (4554, 5)

# %%
df.isnull().sum() 
# 60% of data entries are missing
# Out:
# Statistic Label       0
# Quarter               0
# State                 0
# UNIT                  0
# VALUE              2728
# dtype: int64

# %%
df.describe()
# Out:
#               VALUE
# count   1826.000000
# mean    3977.795016
# std     5587.558500
# min        0.000000
# 25%        7.825000
# 50%       20.050000
# 75%     7348.250000
# max    19950.000000

# %%
df["Statistic Label"].unique
# Out:
# <bound method Series.unique of 0                      Marriages Registered
# 1                      Marriages Registered
# 2                      Marriages Registered
# 3                      Marriages Registered
# 4                      Marriages Registered
#                        ...
# 4549    Average age of mothers giving birth
# 4550    Average age of mothers giving birth
# 4551    Average age of mothers giving birth
# 4552    Average age of mothers giving birth
# 4553    Average age of mothers giving birth
# Name: Statistic Label, Length: 4554, dtype: object>

# %%
fertility = pd.read_csv('Fertility rate OECD.csv')

# %%
fertility.head()
# Out:
#   LOCATION  INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value  Flag Codes
# 0      AUS  FERTILITY     TOT  CHD_WOMAN         A  1960   3.45         NaN
# 1      AUS  FERTILITY     TOT  CHD_WOMAN         A  1961   3.55         NaN
# 2      AUS  FERTILITY     TOT  CHD_WOMAN         A  1962   3.43         NaN
# 3      AUS  FERTILITY     TOT  CHD_WOMAN         A  1963   3.34         NaN
# 4      AUS  FERTILITY     TOT  CHD_WOMAN         A  1964   3.15         NaN

# %%
#Now going forward ireland fertility rate is now saved on IRL
my_value2 = 'IRL'
IRL = fertility.loc[fertility['LOCATION'] == my_value2]
IRL.head()
# Out:
#     LOCATION  INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value  Flag Codes
# 746      IRL  FERTILITY     TOT  CHD_WOMAN         A  1960   3.76         NaN
# 747      IRL  FERTILITY     TOT  CHD_WOMAN         A  1961   3.79         NaN
# 748      IRL  FERTILITY     TOT  CHD_WOMAN         A  1962   3.92         NaN
# 749      IRL  FERTILITY     TOT  CHD_WOMAN         A  1963   4.01         NaN
# 750      IRL  FERTILITY     TOT  CHD_WOMAN         A  1964   4.06         NaN

# %%
#Checking for the shape of the dataset
IRL.shape
# Out:
# (62, 8)

# %%
#Checking for null values
IRL.isnull().sum()
# Out:
# LOCATION       0
# INDICATOR      0
# SUBJECT        0
# MEASURE        0
# FREQUENCY      0
# TIME           0
# Value          0
# Flag Codes    62
# dtype: int64

# %%
# Because we only need the fertility of Ireland/ year, we are not bothered wilthe null valuesin the Flag codes
IRL2= IRL.drop(['Flag Codes',"MEASURE",'SUBJECT','FREQUENCY'], axis=1)
IRL2.head()
#Now we hav edroped the flag co
# Out:
#     LOCATION  INDICATOR  TIME  Value
# 746      IRL  FERTILITY  1960   3.76
# 747      IRL  FERTILITY  1961   3.79
# 748      IRL  FERTILITY  1962   3.92
# 749      IRL  FERTILITY  1963   4.01
# 750      IRL  FERTILITY  1964   4.06

# %%
IRL2.isnull().sum() # No null values
# Out:
# LOCATION     0
# INDICATOR    0
# TIME         0
# Value        0
# dtype: int64

# %%
# The data is distributed evenly
IRL2.describe()
# Out:
#               TIME      Value
# count    62.000000  62.000000
# mean   1990.500000   2.612742
# std      18.041619   0.844956
# min    1960.000000   1.630000
# 25%    1975.250000   1.932500
# 50%    1990.500000   2.085000
# 75%    2005.750000   3.377500
# max    2021.000000   4.060000

# %%
IRL2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 746 to 807
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LOCATION   62 non-null     object
#  1   INDICATOR  62 non-null     object
#  2   TIME       62 non-null     int64
#  3   Value      62 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.5+ KB

# %%
IRL2.duplicated().sum()
# Out:
# 0

# %%
sns.pairplot(data=IRL2, height=10)
